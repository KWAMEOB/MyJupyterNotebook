# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Kwame Owusu Baah**

# %% [markdown]
# *I am interested in Data Science because I want to help solve problems using data, learning more about data science tools and also use them to provide solutions through storytelling to stakeholders for them to understand the data driven solutions.*

# %% [markdown]
# ### In the cell below, I am going substract two numbers and provide an output

# %%
6-2
# Out:
# 4

# %% [markdown]
# List of some roles available for people who are interested in Data Science
# - Business Analyst
# - Data Analyst
# - Databasae Engineer
# - Data Scientist
# - Data Engineer

# %% [markdown]
# Below are some the Languages of Data Science
# 1. Python
# 2. SQL
# 3. R

# %% [markdown]
# ![IBM-Banner.png](attachment:f9390e86-afbc-4ed5-a2a0-4aaba07fe1a3.png)

# %% [markdown]
# [Click here to IBM Data Science Professional Certificate](https://www.coursera.org/professional-certificates/ibm-data-science)
